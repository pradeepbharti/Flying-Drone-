# %% [markdown]
# <a href="https://colab.research.google.com/github/pradeepbharti/Flying-Drone-/blob/master/Copy_of_Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.read_csv('titanic.csv').head()
# Out:
#                    assengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked
# 1\t0\t3\tBraund      Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7...
# 2\t1\t1\tCumings     Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 3\t1\t3\tHeikkinen   Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# 4\t1\t1\tFutrelle    Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 5\t0\t3\tAllen       Mr. William Henry\tmale\t35\t0\t0\t373450\t8....

# %% [markdown]
# ```
# # This is formatted as code
# for item in list:
#     print(item)
# ```

# %% [markdown]
# ![ganesh-chaturthi-festival-lord-ganesh-people-make-decorations-festival-decoration-made-me-ganesh-murti-191396503.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# [Google Search ](https://www.google.com)

# %% [markdown]
# 1.   first
# 2.   second
#
# this is me from
#
# > denver,berlin
#
#
# money heist

# %% [markdown]
# $ ax^2 + bx+c = 0 $

# %%
$x1 = \frac{-b + \sqrt{b^2 - 4ac}}{2a}$

# %% [markdown]
# $x1 = \frac{-b + \sqrt{b^2 - 4ac}}{2a}$
